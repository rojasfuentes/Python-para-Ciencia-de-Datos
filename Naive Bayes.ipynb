# %%
from sklearn.naive_bayes import BernoulliNB
from sklearn.naive_bayes import MultinomialNB
from sklearn.naive_bayes import GaussianNB
import numpy as np
import pandas as pd

df = pd.read_csv("C:/Users/Mayo/Documents/base_datos_2008.csv")
df = df.sample(frac=1)
df = df.head(500000)

# %%
df = df.dropna(subset=["ArrDelay"])

# %%
#Todos los vuelos que se han retrasado al menos un minuto
Y = df["ArrDelay"] > 0

# %%
df["Month"] = df["Month"].apply(str)
df["DayofMonth"] = df["DayofMonth"].apply(str)
df["DayOfWeek"] = df["DayOfWeek"].apply(str)
df["TailNum"] = df["TailNum"].apply(str)

X = pd.get_dummies(data=df[['Month', 'DayofMonth', 'TailNum', 'DayOfWeek', 'Origin', 'Dest', 'UniqueCarrier']])

# %%
#Es el objeto que vamos a usar para intentar predecir si se retrasa o no
X.head()
# Out:
#          Month_1  Month_10  Month_11  Month_12  Month_2  Month_3  Month_4  \
# 5634354        0         1         0         0        0        0        0
# 3849817        0         0         0         0        0        0        0
# 1663529        0         0         0         0        0        1        0
# 4754568        0         0         0         0        0        0        0
# 2397705        0         0         0         0        0        0        0
#
#          Month_5  Month_6  Month_7  ...  UniqueCarrier_HA  UniqueCarrier_MQ  \
# 5634354        0        0        0  ...                 0                 0
# 3849817        0        0        1  ...                 0                 0
# 1663529        0        0        0  ...                 0                 0
# 4754568        0        0        0  ...                 0                 0
# 2397705        1        0        0  ...                 0                 0
#
#          UniqueCarrier_NW  UniqueCarrier_OH  UniqueCarrier_OO  \
# 5634354                 0                 0                 0
# 3849817                 0                 0                 0
# 1663529                 0                 0                 0
# 4754568                 0                 0                 0
# 2397705                 0                 0                 0
#
#          UniqueCarrier_UA  UniqueCarrier_US  UniqueCarrier_WN  \
# 5634354                 0                 1                 0
# 3849817                 1                 0                 0
# 1663529                 0                 0                 0
# 4754568                 0                 0                 0
# 2397705                 0                 0                 1
#
#          UniqueCarrier_XE  UniqueCarrier_YV
# 5634354                 0                 0
# 3849817                 0                 0
# 1663529                 0                 0
# 4754568                 0                 0
# 2397705                 0                 0
#
# [5 rows x 5974 columns]

# %%
#Ajustamos el modelo 

clf = BernoulliNB()
#clf = MultinomialNB()
clf.fit(X, Y)
Y_pred = clf.predict(X)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Input In [6], in <cell line: 5>()
#       3 clf = BernoulliNB()
#       4 #clf = MultinomialNB()
# ----> 5 clf.fit(X, Y)
#       6 Y_pred = clf.predict(X)
#
# File ~\anaconda3\lib\site-packages\sklearn\naive_bayes.py:663, in _BaseDiscreteNB.fit(self, X, y, sample_weight)
#     643 def fit(self, X, y, sample_weight=None):
#     644     """Fit Naive Bayes classifier according to X, y.
#     645
#     646     Parameters
#    (...)
#     661         Returns the instance itself.
#     662     """
# --> 663     X, y = self._check_X_y(X, y)
#     664     _, n_features = X.shape
#     666     labelbin = LabelBinarizer()
#
# File ~\anaconda3\lib\site-packages\sklearn\naive_bayes.py:1155, in BernoulliNB._check_X_y(self, X, y, reset)
#    1153 X, y = super()._check_X_y(X, y, reset=reset)
#    1154 if self.binarize is not None:
# -> 1155     X = binarize(X, threshold=self.binarize)
#    1156 return X, y
#
# File ~\anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2003, in binarize(X, threshold, copy)
#    2001 else:
#    2002     cond = X > threshold
# -> 2003     not_cond = np.logical_not(cond)
#    2004     X[cond] = 1
#    2005     X[not_cond] = 0
#
# MemoryError: Unable to allocate 2.72 GiB for an array with shape (488861, 5974) and data type bool

# %%
np.mean(Y == Y_pred)

# %%
1 - np.mean(Y)

# %%
x = df[['AirTime', 'Distance', 'TaxiIn', 'TaxiOut']] #DepDelay
clf = GaussianNB()
clf.fit(X, Y)
Y_pred = clf.predict(X)

# %%
np.mean(Y == Y_pred)
