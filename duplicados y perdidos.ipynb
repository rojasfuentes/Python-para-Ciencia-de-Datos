# %%
import pandas as pd
df = pd.read_csv("C:/Users/Mayo/Documents/base_datos_2008.csv", nrows=1e6)
#cargamos millones de datos

# %%
dfduplicate = df.append(df)
# Out:
# C:\Users\Mayo\AppData\Local\Temp\ipykernel_7200\20558261.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfduplicate = df.append(df)

# %%
#Lo reordenamos
dfduplicate = dfduplicate.sample(frac=1)

# %%
#Eliminamos los casos faltantes
dfclean = dfduplicate.drop_duplicates()

# %%
len(df)
# Out:
# 7009728

# %%
len(dfclean)
# Out:
# 7009724

# %%
len(dfduplicate)
# Out:
# 14019456

# %%
#subset busca duplicados sobre la columna que le especifiquemos 
dfclean.drop_duplicates(subset = 'DayofMonth')
# Out:
#          Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 2158004  2008      4          28          1   1435.0        1440   1818.0
# 5380803  2008      9          12          5   1105.0        1110   1132.0
# 1541306  2008      3          11          2   1513.0        1509   1726.0
# 1765189  2008      3          21          5    644.0         650    733.0
# 6221179  2008     11          29          6    828.0         830   1117.0
# 1547957  2008      3          20          4   1857.0        1859   2040.0
# 1065177  2008      2          19          2   1212.0        1200   1404.0
# 6128431  2008     11           6          4   1511.0        1517   1558.0
# 2426880  2008      5          14          3   1346.0        1340   1927.0
# 3830680  2008      7           1          2    724.0         733   1617.0
# 195310   2008      1          17          4   1958.0        1958   2132.0
# 4524415  2008      8          24          7    649.0         648    842.0
# ...

# %%
#dropna elimina los datos null 
#thresh seleccionamos cuantas columnas queremos que mantengan información relevante 
df.dropna(thresh=25)
# Out:
#          Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 4        2008      1           3          4   1829.0        1755   1959.0
# 6        2008      1           3          4   1937.0        1830   2037.0
# 11       2008      1           3          4   1644.0        1510   1845.0
# 16       2008      1           3          4   1452.0        1425   1640.0
# 18       2008      1           3          4   1323.0        1255   1526.0
# ...       ...    ...         ...        ...      ...         ...      ...
# 7009715  2008     12          13          6    848.0         850   1024.0
# 7009717  2008     12          13          6    657.0         600    904.0
# 7009718  2008     12          13          6   1007.0         847   1149.0
# 7009719  2008     12          13          6    638.0         640    808.0
# 7009721  2008     12          13          6    612.0         615    923.0
#
#          CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# ...

# %%
df.dropna(thresh=len(df.columns)-2)
# Out:
#          Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 4        2008      1           3          4   1829.0        1755   1959.0
# 6        2008      1           3          4   1937.0        1830   2037.0
# 11       2008      1           3          4   1644.0        1510   1845.0
# 16       2008      1           3          4   1452.0        1425   1640.0
# 18       2008      1           3          4   1323.0        1255   1526.0
# ...       ...    ...         ...        ...      ...         ...      ...
# 7009715  2008     12          13          6    848.0         850   1024.0
# 7009717  2008     12          13          6    657.0         600    904.0
# 7009718  2008     12          13          6   1007.0         847   1149.0
# 7009719  2008     12          13          6    638.0         640    808.0
# 7009721  2008     12          13          6    612.0         615    923.0
#
#          CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# ...

# %%
df.dropna(subset = ["CancellationCode"])
# Out:
#          Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 178      2008      1           3          4      NaN         700      NaN
# 373      2008      1           3          4      NaN        1100      NaN
# 399      2008      1           3          4      NaN         905      NaN
# 401      2008      1           3          4      NaN        1620      NaN
# 415      2008      1           3          4      NaN        1930      NaN
# ...       ...    ...         ...        ...      ...         ...      ...
# 7009455  2008     12          13          6      NaN         600      NaN
# 7009464  2008     12          13          6      NaN        1930      NaN
# 7009564  2008     12          13          6      NaN         700      NaN
# 7009565  2008     12          13          6      NaN        1115      NaN
# 7009648  2008     12          13          6      NaN        1020      NaN
#
#          CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# ...
