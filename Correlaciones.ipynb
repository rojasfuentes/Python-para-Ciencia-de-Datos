# %%
import pandas as pd
import numpy as np
df = pd.read_csv("C:/Users/Mayo/Documents/base_datos_2008.csv", nrows = 10000)

# %%
df.dropna(inplace=True, subset=["ArrDelay", "DepDelay"])

# %%
np.corrcoef(df["ArrDelay"], df["DepDelay"])
# Out:
# array([[1.        , 0.95453694],
#        [0.95453694, 1.        ]])

# %%
np.corrcoef([df["ArrDelay"], df["DepDelay"], df["DepTime"]])
# Out:
# array([[1.        , 0.95453694, 0.40926916],
#        [0.95453694, 1.        , 0.43059119],
#        [0.40926916, 0.43059119, 1.        ]])

# %%
#Primero tenemos que eliminar las columnas que no sean numéricas
df.drop(inplace=True, columns = ["Year", "Cancelled", "Diverted"])

# %%
df.corr()
# Out:
#                    Month  DayofMonth  DayOfWeek   DepTime  CRSDepTime  \
# Month                NaN         NaN        NaN       NaN         NaN
# DayofMonth           NaN    1.000000   1.000000  0.006041    0.016105
# DayOfWeek            NaN    1.000000   1.000000  0.006041    0.016105
# DepTime              NaN    0.006041   0.006041  1.000000    0.992387
# CRSDepTime           NaN    0.016105   0.016105  0.992387    1.000000
# ArrTime              NaN    0.021621   0.021621  0.717508    0.725912
# CRSArrTime           NaN    0.009962   0.009962  0.846729    0.854494
# FlightNum            NaN   -0.052462  -0.052462  0.010975    0.010790
# ActualElapsedTime    NaN   -0.009423  -0.009423 -0.073140   -0.081637
# CRSElapsedTime       NaN   -0.012451  -0.012451 -0.071329   -0.079229
# AirTime              NaN   -0.007292  -0.007292 -0.071030   -0.078009
# ArrDelay             NaN   -0.063383  -0.063383  0.409269    0.314830
# ...

# %%
#El estilo que usamos muestra un degradado según la intensidad de la correlacion
df.drop(inplace = True, columns = ["Month"])
#Redondeamos la matriz para que no tenga numeros decimales (solo 3)
corr= round(df.corr(),3)
corr.style.background_gradient()
# Out:
# <style type="text/css">
# #T_e58a9_row0_col0, #T_e58a9_row0_col1, #T_e58a9_row1_col0, #T_e58a9_row1_col1, #T_e58a9_row2_col2, #T_e58a9_row3_col3, #T_e58a9_row4_col4, #T_e58a9_row5_col5, #T_e58a9_row6_col6, #T_e58a9_row7_col7, #T_e58a9_row8_col8, #T_e58a9_row9_col9, #T_e58a9_row10_col10, #T_e58a9_row11_col11, #T_e58a9_row12_col12, #T_e58a9_row13_col13, #T_e58a9_row14_col14, #T_e58a9_row15_col15, #T_e58a9_row16_col16, #T_e58a9_row17_col17, #T_e58a9_row18_col18, #T_e58a9_row19_col19 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_e58a9_row0_col2, #T_e58a9_row1_col2, #T_e58a9_row15_col2 {
#   background-color: #e8e4f0;
#   color: #000000;
# }
# #T_e58a9_row0_col3, #T_e58a9_row1_col3 {
#   background-color: #e5e1ef;
#   color: #000000;
# }
# ...
